# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # Generate Data

# %%
import requests
from tqdm import tqdm
from torch.utils.data import Dataset
from torch.autograd import Variable
import torch
import os
import numpy as np
import re
import zipfile
import itertools
from collections import namedtuple
import matplotlib.pyplot as plt

# %%
# Training Data
class TSPDataset(Dataset):
    
    def __init__(self, dataset_fname=None, train=False, size=50, num_samples=100000, random_seed=1111):
        super(TSPDataset, self).__init__()
        
        torch.manual_seed(random_seed)

        self.data_set = []
        
        # randomly sample points uniformly from [0, 1]
        for l in tqdm(range(num_samples)):
            x = torch.FloatTensor(2, size).uniform_(0, 1)
            #x = torch.cat([start, x], 1)
            self.data_set.append(x)

        self.size = len(self.data_set)

    def __len__(self):
        return self.size

    def __getitem__(self, idx):
        return self.data_set[idx]

# %% [markdown]
# ## DataLoader

# %%
import pprint as pp
import numpy as np

import torch
from torch.utils.data import DataLoader

# %%
128*15000
# Out:
# 1920000

# %%
input_dim = 2
size =50
train_size = 1920000
val_size = 1000
batch_size = 128

# %%
training_dataset = TSPDataset(train=True, size=size,
     num_samples=train_size)

val_dataset = TSPDataset(train=True, size=size,
        num_samples=val_size)

train_dataloader = DataLoader(training_dataset, batch_size=batch_size,
    shuffle=True, num_workers=4)

val_dataloader = DataLoader(val_dataset, batch_size=1, shuffle=True, num_workers=1)
# Out:
# 100%|██████████| 1920000/1920000 [00:11<00:00, 161179.23it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 111384.75it/s]

# %% [markdown]
# # Neural Net Model

# %% [markdown]
# ## Encoder

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
from torch.autograd import Variable
import torch.nn.functional as F
import math
import numpy as np

# %%
class Encoder(nn.Module):
    """Maps a graph represented as an input sequence
    to a hidden vector"""
    def __init__(self, input_dim, hidden_dim, use_cuda):
        super(Encoder, self).__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim)
        self.use_cuda = use_cuda
        self.enc_init_state = self.init_hidden(hidden_dim)

    def forward(self, x, hidden):
        output, hidden = self.lstm(x, hidden)
        return output, hidden
    
    def init_hidden(self, hidden_dim):
        """Trainable initial hidden state"""
        enc_init_hx = Variable(torch.zeros(hidden_dim), requires_grad=False)
        if self.use_cuda:
            enc_init_hx = enc_init_hx.cuda()

        #enc_init_hx.data.uniform_(-(1. / math.sqrt(hidden_dim)),
        #        1. / math.sqrt(hidden_dim))

        enc_init_cx = Variable(torch.zeros(hidden_dim), requires_grad=False)
        if self.use_cuda:
            enc_init_cx = enc_init_cx.cuda()

        #enc_init_cx = nn.Parameter(enc_init_cx)
        #enc_init_cx.data.uniform_(-(1. / math.sqrt(hidden_dim)),
        #        1. / math.sqrt(hidden_dim))
        return (enc_init_hx, enc_init_cx)

# %% [markdown]
# ## Attention

# %%
class Attention(nn.Module):
    """A generic attention module for a decoder in seq2seq"""
    def __init__(self, dim, use_tanh=False, C=10, use_cuda=True):
        super(Attention, self).__init__()
        self.use_tanh = use_tanh
        # query matrix W_q
        self.project_query = nn.Linear(dim, dim)
        # refence matrix W_ref
        self.project_ref = nn.Conv1d(dim, dim, 1, 1)
        self.C = C  # tanh exploration
        self.tanh = nn.Tanh()
        
        v = torch.FloatTensor(dim)
        if use_cuda:
            v = v.cuda()  
        self.v = nn.Parameter(v)
        self.v.data.uniform_(-(1. / math.sqrt(dim)) , 1. / math.sqrt(dim))
        
    def forward(self, query, ref):
        """
        Args: 
            query: is the hidden state of the decoder at the current
                time step. batch x dim
            ref: the set of hidden states from the encoder. 
                sourceL x batch x hidden_dim
        """
        # ref is now [batch_size x hidden_dim x sourceL]
        ref = ref.permute(1, 2, 0)
        q = self.project_query(query).unsqueeze(2)  # batch x dim x 1
        e = self.project_ref(ref)  # batch_size x hidden_dim x sourceL 
        # expand the query by sourceL
        # batch x dim x sourceL
        expanded_q = q.repeat(1, 1, e.size(2)) 
        # batch x 1 x hidden_dim
        v_view = self.v.unsqueeze(0).expand(
                expanded_q.size(0), len(self.v)).unsqueeze(1)
        # [batch_size x 1 x hidden_dim] * [batch_size x hidden_dim x sourceL]
        u = torch.bmm(v_view, self.tanh(expanded_q + e)).squeeze(1)
        if self.use_tanh:
            logits = self.C * self.tanh(u)
        else:
            logits = u  
            
        # e is projected reference, logits is u
        # ref is used to compute glimpse: G = ref * softmax(u)
        
        # the logits has the same length with the number of cities
        # so softmax(logits) is exact the probability of each city
        return e, logits

# %% [markdown]
# ## Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, 
            embedding_dim,
            hidden_dim,
            max_length,
            tanh_exploration,
            terminating_symbol,
            use_tanh,
            decode_type,
            n_glimpses=1,
            beam_size=0,
            use_cuda=True):
        super(Decoder, self).__init__()
        
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.n_glimpses = n_glimpses
        self.max_length = max_length
        self.terminating_symbol = terminating_symbol 
        self.decode_type = decode_type
        self.beam_size = beam_size
        self.use_cuda = use_cuda

        self.input_weights = nn.Linear(embedding_dim, 4 * hidden_dim)
        self.hidden_weights = nn.Linear(hidden_dim, 4 * hidden_dim)

        self.pointer = Attention(hidden_dim, use_tanh=use_tanh, C=tanh_exploration, use_cuda=self.use_cuda)
        self.glimpse = Attention(hidden_dim, use_tanh=False, use_cuda=self.use_cuda)
        self.sm = nn.Softmax(dim=-1)

    def apply_mask_to_logits(self, step, logits, mask, prev_idxs):    
        if mask is None:
            mask = torch.zeros(logits.size()).byte()
            if self.use_cuda:
                mask = mask.cuda()
    
        maskk = mask.clone()

        # to prevent them from being reselected. 
        # Or, allow re-selection and penalize in the objective function
        if prev_idxs is not None:
            # set most recently selected idx values to 1
            maskk[[x for x in range(logits.size(0))],
                    prev_idxs.data] = 1
            # just implement the equation (8) in the paper
            logits[maskk] = -np.inf
        return logits, maskk

    def forward(self, decoder_input, embedded_inputs, hidden, context):

        def recurrence(x, hidden, logit_mask, prev_idxs, step):
            
            hx, cx = hidden  # batch_size x hidden_dim
            
            gates = self.input_weights(x) + self.hidden_weights(hx)
            ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)

            ingate = torch.sigmoid(ingate)
            forgetgate = torch.sigmoid(forgetgate)
            cellgate = torch.tanh(cellgate)
            outgate = torch.sigmoid(outgate)

            cy = (forgetgate * cx) + (ingate * cellgate)
            hy = outgate * torch.tanh(cy)  # batch_size x hidden_dim
            
            g_l = hy
            for i in range(self.n_glimpses):
                ref, logits = self.glimpse(g_l, context)
                logits, logit_mask = self.apply_mask_to_logits(step, logits, logit_mask, prev_idxs)
                # [batch_size x h_dim x sourceL] * [batch_size x sourceL x 1] = 
                # [batch_size x h_dim x 1]
                g_l = torch.bmm(ref, self.sm(logits).unsqueeze(2)).squeeze(2) 
            _, logits = self.pointer(g_l, context)
            
            hidden_logits = logits.clone()
            # update the mask
            logits, logit_mask = self.apply_mask_to_logits(step, logits, logit_mask, prev_idxs)
            probs = self.sm(logits)
            return hy, cy, probs, logit_mask, hidden_logits
    
        batch_size = context.size(1)
        outputs = []
        selections = []
        hidden_logits = []
        steps = range(self.max_length)  # or until terminating symbol ?
        inps = []
        idxs = None
        mask = None
       
        if self.decode_type == "stochastic":
            # for loop to get all city coordinates
            for i in steps:
                # the first decoder_input is just a trainable parameters
                # the next decoder_input is the embedded_inputs[idxs]
                hx, cx, probs, mask, h_logits = recurrence(decoder_input, hidden, mask, idxs, i)
                # hidden contains two tensors with size [batch_size x hidden_dim]
                # and the (hy, cy) is the next (hx, cx)
                # the first hidden comes from the encoder
                hidden = (hx, cx)
                # select the next inputs for the decoder [batch_size x hidden_dim]
                decoder_input, idxs = self.decode_stochastic(
                    probs,
                    embedded_inputs,
                    selections)
                inps.append(decoder_input) 
                # use outs to point to next object
                outputs.append(probs)
                selections.append(idxs)
                hidden_logits.append(h_logits)
            return (outputs, selections), hidden, hidden_logits
                
        elif self.decode_type == "greedy":
            for i in steps:
                hx, cx, probs, mask, h_logits = recurrence(decoder_input, hidden, mask, idxs, i)
                hidden = (hx, cx)
                decoder_input, idxs = self.decode_greedy(
                    probs,
                    embedded_inputs,
                    selections)
                inps.append(decoder_input) 
                outputs.append(probs)
                selections.append(idxs)
                hidden_logits.append(h_logits)
            return (outputs, selections), hidden, hidden_logits
        
    def decode_stochastic(self, probs, embedded_inputs, selections):
        """
        Return the next input for the decoder by selecting the 
        input corresponding to the max output
        Args: 
            probs: [batch_size x sourceL]
            embedded_inputs: [sourceL x batch_size x embedding_dim]
            selections: list of all of the previously selected indices during decoding
       Returns:
            Tensor of size [batch_size x sourceL] containing the embeddings
            from the inputs corresponding to the [batch_size] indices
            selected for this iteration of the decoding, as well as the 
            corresponding indicies
        """
        batch_size = probs.size(0)
        # idxs is [batch_size]
        # idxs = probs.multinomial().squeeze(1)
        # idxs is the sampled city index
        c = torch.distributions.Categorical(probs)
        
        idxs = c.sample()
        
        # due to race conditions, might need to resample here
        for old_idxs in selections:
            # compare new idxs
            # elementwise with the previous idxs. If any matches,
            # then need to resample
            if old_idxs.eq(idxs).data.any():
                print(' [!] resampling due to race condition')
                idxs = probs.multinomial().squeeze(1)
                break
        
        # embedded inputs are the embedded city coordinates, the next index is idxs,
        # so the next embedded input is embedded_inputs[idex]
        sels = embedded_inputs[idxs.data, [i for i in range(batch_size)], :] 
        return sels, idxs
    
    def decode_greedy(self, probs, embedded_inputs, selections):

        batch_size = probs.size(0)
        # idxs is [batch_size]
        # idxs is the greedy city index
        _, idxs = torch.max(probs,1)
        
        # embedded inputs are the embedded city coordinates, the next index is idxs,
        # so the next embedded input is embedded_inputs[idex]
        sels = embedded_inputs[idxs.data, [i for i in range(batch_size)], :] 
        return sels, idxs

# %%
class DecoderHigh(nn.Module):
    def __init__(self, 
            embedding_dim,
            hidden_dim,
            max_length,
            tanh_exploration,
            terminating_symbol,
            use_tanh,
            decode_type,
            n_glimpses=1,
            beam_size=0,
            use_cuda=True):
        super(DecoderHigh, self).__init__()
        
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.n_glimpses = n_glimpses
        self.max_length = max_length
        self.terminating_symbol = terminating_symbol 
        self.decode_type = decode_type
        self.beam_size = beam_size
        self.use_cuda = use_cuda

        self.input_weights = nn.Linear(embedding_dim, 4 * hidden_dim)
        self.hidden_weights = nn.Linear(hidden_dim, 4 * hidden_dim)

        self.pointer = Attention(hidden_dim, use_tanh=use_tanh, C=tanh_exploration, use_cuda=self.use_cuda)
        self.glimpse = Attention(hidden_dim, use_tanh=False, use_cuda=self.use_cuda)
        self.sm = nn.Softmax(dim=-1)

    def apply_mask_to_logits(self, step, logits, mask, prev_idxs):    
        if mask is None:
            mask = torch.zeros(logits.size()).byte()
            if self.use_cuda:
                mask = mask.cuda()
    
        maskk = mask.clone()

        # to prevent them from being reselected. 
        # Or, allow re-selection and penalize in the objective function
        if prev_idxs is not None:
            # set most recently selected idx values to 1
            maskk[[x for x in range(logits.size(0))],
                    prev_idxs.data] = 1
            # just implement the equation (8) in the paper
            logits[maskk] = -np.inf
        return logits, maskk

    def forward(self, decoder_input, embedded_inputs, hidden, context, hidden_logits):
        """
        Args:
            decoder_input: The initial input to the decoder
                size is [batch_size x embedding_dim]. Trainable parameter.
            embedded_inputs: [sourceL x batch_size x embedding_dim]
            hidden: the prev hidden state, size is [batch_size x hidden_dim]. 
                Initially this is set to (enc_h[-1], enc_c[-1])
            context: encoder outputs, [sourceL x batch_size x hidden_dim] 
        """
        def recurrence(x, hidden, logit_mask, prev_idxs, step, hidden_logit):
            
            hx, cx = hidden  # batch_size x hidden_dim
            
            gates = self.input_weights(x) + self.hidden_weights(hx)
            ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)

            ingate = torch.sigmoid(ingate)
            forgetgate = torch.sigmoid(forgetgate)
            cellgate = torch.tanh(cellgate)
            outgate = torch.sigmoid(outgate)

            cy = (forgetgate * cx) + (ingate * cellgate)
            hy = outgate * torch.tanh(cy)  # batch_size x hidden_dim
            
            g_l = hy
            for i in range(self.n_glimpses):
                ref, logits = self.glimpse(g_l, context)
                logits, logit_mask = self.apply_mask_to_logits(step, logits, logit_mask, prev_idxs)
                # [batch_size x h_dim x sourceL] * [batch_size x sourceL x 1] = 
                # [batch_size x h_dim x 1]
                g_l = torch.bmm(ref, self.sm(logits).unsqueeze(2)).squeeze(2) 
            _, logits = self.pointer(g_l, context)
            logits = logits + hidden_logit
            # update the mask
            logits, logit_mask = self.apply_mask_to_logits(step, logits, logit_mask, prev_idxs)

            probs = self.sm(logits)
            return hy, cy, probs, logit_mask
    
        batch_size = context.size(1)
        outputs = []
        selections = []
        steps = range(self.max_length)  # or until terminating symbol ?
        inps = []
        idxs = None
        mask = None
       
        if self.decode_type == "stochastic":
            # for loop to get all city coordinates
            for i in steps:
                # input the hidden_logits[i]
                hx, cx, probs, mask = recurrence(decoder_input, hidden, mask, idxs, i, hidden_logits[i])

                # select the next inputs for the decoder [batch_size x hidden_dim]
                decoder_input, idxs = self.decode_stochastic(
                    probs,
                    embedded_inputs,
                    selections)
                inps.append(decoder_input) 
                # use outs to point to next object
                outputs.append(probs)
                selections.append(idxs)
            return (outputs, selections), hidden
                
        elif self.decode_type == "greedy":
            for i in steps:
                hx, cx, probs, mask = recurrence(decoder_input, hidden, mask, idxs, i, hidden_logits[i])
                hidden = (hx, cx)
                decoder_input, idxs = self.decode_greedy(
                    probs,
                    embedded_inputs,
                    selections)
                inps.append(decoder_input) 
                outputs.append(probs)
                selections.append(idxs)
                
            return (outputs, selections), hidden
        
    def decode_stochastic(self, probs, embedded_inputs, selections):
        """
        Return the next input for the decoder by selecting the 
        input corresponding to the max output
        Args: 
            probs: [batch_size x sourceL]
            embedded_inputs: [sourceL x batch_size x embedding_dim]
            selections: list of all of the previously selected indices during decoding
       Returns:
            Tensor of size [batch_size x sourceL] containing the embeddings
            from the inputs corresponding to the [batch_size] indices
            selected for this iteration of the decoding, as well as the 
            corresponding indicies
        """
        batch_size = probs.size(0)
        # idxs is [batch_size]
        # idxs = probs.multinomial().squeeze(1)
        # idxs is the sampled city index
        c = torch.distributions.Categorical(probs)
        
        idxs = c.sample()
        
        # due to race conditions, might need to resample here
        for old_idxs in selections:
            # compare new idxs
            # elementwise with the previous idxs. If any matches,
            # then need to resample
            if old_idxs.eq(idxs).data.any():
                print(' [!] resampling due to race condition')
                idxs = probs.multinomial().squeeze(1)
                break
        
        # embedded inputs are the embedded city coordinates, the next index is idxs,
        # so the next embedded input is embedded_inputs[idex]
        sels = embedded_inputs[idxs.data, [i for i in range(batch_size)], :] 
        return sels, idxs
    
    def decode_greedy(self, probs, embedded_inputs, selections):

        batch_size = probs.size(0)
        # idxs is [batch_size]
        # idxs is the greedy city index
        _, idxs = torch.max(probs,1)
        
        # embedded inputs are the embedded city coordinates, the next index is idxs,
        # so the next embedded input is embedded_inputs[idex]
        sels = embedded_inputs[idxs.data, [i for i in range(batch_size)], :] 
        return sels, idxs

# %% [markdown]
# ## Pointer Network

# %%
class PointerNetwork(nn.Module):
    """
    The pointer network, which is the core seq2seq model
    """
    def __init__(self, 
            embedding_dim,
            hidden_dim,
            max_decoding_len,
            terminating_symbol,
            n_glimpses,
            tanh_exploration,
            use_tanh,
            beam_size,
            use_cuda):
        super(PointerNetwork, self).__init__()

        self.encoder = Encoder(
                embedding_dim,
                hidden_dim,
                use_cuda)

        self.decoder = Decoder(
                embedding_dim,
                hidden_dim,
                max_length=max_decoding_len,
                tanh_exploration=tanh_exploration,
                use_tanh=use_tanh,
                terminating_symbol=terminating_symbol,
                decode_type="stochastic",
                n_glimpses=n_glimpses,
                beam_size=beam_size,
                use_cuda=use_cuda)

        # Trainable initial hidden states
        dec_in_0 = torch.FloatTensor(embedding_dim)
        if use_cuda:
            dec_in_0 = dec_in_0.cuda()

        self.decoder_in_0 = nn.Parameter(dec_in_0)
        self.decoder_in_0.data.uniform_(-(1. / math.sqrt(embedding_dim)),
                1. / math.sqrt(embedding_dim))
            
    def forward(self, inputs):
        """ Propagate inputs through the network
        Args: 
            inputs: [sourceL x batch_size x embedding_dim]
        """
        
        (encoder_hx, encoder_cx) = self.encoder.enc_init_state
        encoder_hx = encoder_hx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)       
        encoder_cx = encoder_cx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)       
        
        # encoder forward pass
        enc_h, (enc_h_t, enc_c_t) = self.encoder(inputs, (encoder_hx, encoder_cx))

        dec_init_state = (enc_h_t[-1], enc_c_t[-1])
    
        '''
        The first decoder_input is just the random trainable parameters
        
        The inputs are the embedded x (city coordinates)
        
        The initial decoder hidden states are the first encoded hidden variable
        
        The encoded latent variable is passed in decoder as the context, also
        as the reference in the attention
        '''
    
        # repeat decoder_in_0 across batch
        decoder_input = self.decoder_in_0.unsqueeze(0).repeat(inputs.size(1), 1)
        
        (pointer_probs, input_idxs), dec_hidden_t, hidden_logits = self.decoder(decoder_input,
                inputs,
                dec_init_state,
                enc_h)
        
        return pointer_probs, input_idxs, hidden_logits

# %%
class PointerNetworkHigh(nn.Module):
    """
    The pointer network, which is the core seq2seq model
    """
    def __init__(self, 
            embedding_dim,
            hidden_dim,
            max_decoding_len,
            terminating_symbol,
            n_glimpses,
            tanh_exploration,
            use_tanh,
            beam_size,
            use_cuda):
        super(PointerNetworkHigh, self).__init__()

        self.encoder = Encoder(
                embedding_dim,
                hidden_dim,
                use_cuda)

        self.decoder = DecoderHigh(
                embedding_dim,
                hidden_dim,
                max_length=max_decoding_len,
                tanh_exploration=tanh_exploration,
                use_tanh=use_tanh,
                terminating_symbol=terminating_symbol,
                decode_type="stochastic",
                n_glimpses=n_glimpses,
                beam_size=beam_size,
                use_cuda=use_cuda)

        # Trainable initial hidden states
        dec_in_0 = torch.FloatTensor(embedding_dim)
        if use_cuda:
            dec_in_0 = dec_in_0.cuda()

        self.decoder_in_0 = nn.Parameter(dec_in_0)
        self.decoder_in_0.data.uniform_(-(1. / math.sqrt(embedding_dim)),
                1. / math.sqrt(embedding_dim))
            
    def forward(self, inputs, hidden_logits):
        """ Propagate inputs through the network
        Args: 
            inputs: [sourceL x batch_size x embedding_dim]
        """
        
        (encoder_hx, encoder_cx) = self.encoder.enc_init_state
        encoder_hx = encoder_hx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)       
        encoder_cx = encoder_cx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)       
        
        # encoder forward pass
        enc_h, (enc_h_t, enc_c_t) = self.encoder(inputs, (encoder_hx, encoder_cx))

        dec_init_state = (enc_h_t[-1], enc_c_t[-1])
    
        '''
        The first decoder_input is just the random trainable parameters
        
        The inputs are the embedded x (city coordinates)
        
        The initial decoder hidden states are the first encoded hidden variable
        
        The encoded latent variable is passed in decoder as the context, also
        as the reference in the attention
        '''
    
        # repeat decoder_in_0 across batch
        decoder_input = self.decoder_in_0.unsqueeze(0).repeat(inputs.size(1), 1)
        
        (pointer_probs, input_idxs), dec_hidden_t = self.decoder(decoder_input,
                inputs,
                dec_init_state,
                enc_h, 
                hidden_logits)
        
        return pointer_probs, input_idxs

# %% [markdown]
# ## Critic Network

# %%
class CriticNetwork(nn.Module):
    """Useful as a baseline in REINFORCE updates"""
    def __init__(self,
            embedding_dim,
            hidden_dim,
            n_process_block_iters,
            tanh_exploration,
            use_tanh,
            use_cuda):
        super(CriticNetwork, self).__init__()
        
        self.hidden_dim = hidden_dim
        self.n_process_block_iters = n_process_block_iters

        self.encoder = Encoder(
                embedding_dim,
                hidden_dim,
                use_cuda)
        
        self.process_block = Attention(hidden_dim,
                use_tanh=use_tanh, C=tanh_exploration, use_cuda=use_cuda)
        self.sm = nn.Softmax(dim=-1)
        self.decoder = nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, 1)
        )

    def forward(self, inputs):
        """
        Args:
            inputs: [embedding_dim x batch_size x sourceL] of embedded inputs
        """
         
        (encoder_hx, encoder_cx) = self.encoder.enc_init_state
        encoder_hx = encoder_hx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)
        encoder_cx = encoder_cx.unsqueeze(0).repeat(inputs.size(1), 1).unsqueeze(0)       
        
        # encoder forward pass
        enc_outputs, (enc_h_t, enc_c_t) = self.encoder(inputs, (encoder_hx, encoder_cx))
        
        # grab the hidden state and process it via the process block 
        process_block_state = enc_h_t[-1]
        for i in range(self.n_process_block_iters):
            ref, logits = self.process_block(process_block_state, enc_outputs)
            process_block_state = torch.bmm(ref, self.sm(logits).unsqueeze(2)).squeeze(2)
        # produce the final scalar output
        out = self.decoder(process_block_state)
        return out

# %% [markdown]
# ## Final Model

# %%
class NeuralCombOptRL(nn.Module):
    """
    This module contains the PointerNetwork (actor) and
    CriticNetwork (critic). It requires
    an application-specific reward function
    """
    def __init__(self, 
            input_dim,
            embedding_dim,
            hidden_dim,
            max_decoding_len,
            terminating_symbol,
            n_glimpses,
            n_process_block_iters,
            tanh_exploration,
            use_tanh,
            beam_size,
            objective_fn,
            is_train,
            use_cuda):
        super(NeuralCombOptRL, self).__init__()
        self.objective_fn = objective_fn
        self.input_dim = input_dim
        self.is_train = is_train
        self.use_cuda = use_cuda

        
        self.actor_net = PointerNetwork(
                embedding_dim,
                hidden_dim,
                max_decoding_len,
                terminating_symbol,
                n_glimpses,
                tanh_exploration,
                use_tanh,
                beam_size,
                use_cuda)
        
        #self.critic_net = CriticNetwork(
        #        embedding_dim,
        #        hidden_dim,
        #        n_process_block_iters,
        #        tanh_exploration,
        #        False,
        #        use_cuda)
       
        embedding_ = torch.FloatTensor(input_dim,
            embedding_dim)
        if self.use_cuda: 
            embedding_ = embedding_.cuda()
        self.embedding = nn.Parameter(embedding_) 
        self.embedding.data.uniform_(-(1. / math.sqrt(embedding_dim)),
            1. / math.sqrt(embedding_dim))

    def forward(self, inputs):
        """
        Args:
            inputs: [batch_size, input_dim, sourceL]
        """
        batch_size = inputs.size(0)
        input_dim = inputs.size(1)
        sourceL = inputs.size(2)

        # repeat embeddings across batch_size
        # result is [batch_size x input_dim x embedding_dim]
        embedding = self.embedding.repeat(batch_size, 1, 1)  
        embedded_inputs = []
        # result is [batch_size, 1, input_dim, sourceL] 
        ips = inputs.unsqueeze(1)
        
        for i in range(sourceL):
            # [batch_size x 1 x input_dim] * [batch_size x input_dim x embedding_dim]
            # result is [batch_size, embedding_dim]
            embedded_inputs.append(torch.bmm(
                ips[:, :, :, i].float(),
                embedding).squeeze(1))

        # Result is [sourceL x batch_size x embedding_dim]
        embedded_inputs = torch.cat(embedded_inputs).view(
                sourceL,
                batch_size,
                embedding.size(2))

        # query the actor net for the input indices 
        # making up the output, and the pointer attn 
        probs_, action_idxs, hidden_logits = self.actor_net(embedded_inputs)
       
        # Select the actions (inputs pointed to 
        # by the pointer net) and the corresponding
        # logits
        # should be size [batch_size x 
        actions = []
        # inputs is [batch_size, input_dim, sourceL]
        inputs_ = inputs.transpose(1, 2)
        # inputs_ is [batch_size, sourceL, input_dim]
        for action_id in action_idxs:
            actions.append(inputs_[[x for x in range(batch_size)], action_id.data, :])

        if self.is_train:
            # probs_ is a list of len sourceL of [batch_size x sourceL]
            probs = []
            for prob, action_id in zip(probs_, action_idxs):
                probs.append(prob[[x for x in range(batch_size)], action_id.data])
        else:
            # return the list of len sourceL of [batch_size x sourceL]
            probs = probs_

        # get the critic value fn estimates for the baseline
        # [batch_size]
        #v = self.critic_net(embedded_inputs)
    
        # [batch_size]
        R, C = self.objective_fn(actions, self.use_cuda)
        
        #return R, v, probs, actions, action_idxs
        return R, C, probs, actions, action_idxs, hidden_logits

# %%
class NeuralCombOptRLHigh(nn.Module):
    """
    This module contains the PointerNetwork (actor) and
    CriticNetwork (critic). It requires
    an application-specific reward function
    """
    def __init__(self, 
            input_dim,
            embedding_dim,
            hidden_dim,
            max_decoding_len,
            terminating_symbol,
            n_glimpses,
            n_process_block_iters,
            tanh_exploration,
            use_tanh,
            beam_size,
            objective_fn,
            is_train,
            use_cuda):
        super(NeuralCombOptRLHigh, self).__init__()
        self.objective_fn = objective_fn
        self.input_dim = input_dim
        self.is_train = is_train
        self.use_cuda = use_cuda

        
        self.actor_net = PointerNetworkHigh(
                embedding_dim,
                hidden_dim,
                max_decoding_len,
                terminating_symbol,
                n_glimpses,
                tanh_exploration,
                use_tanh,
                beam_size,
                use_cuda)
        
        #self.critic_net = CriticNetwork(
        #        embedding_dim,
        #        hidden_dim,
        #        n_process_block_iters,
        #        tanh_exploration,
        #        False,
        #        use_cuda)
       
        embedding_ = torch.FloatTensor(input_dim,
            embedding_dim)
        if self.use_cuda: 
            embedding_ = embedding_.cuda()
        self.embedding = nn.Parameter(embedding_) 
        self.embedding.data.uniform_(-(1. / math.sqrt(embedding_dim)),
            1. / math.sqrt(embedding_dim))

    def forward(self, inputs, hidden_logits):
        """
        Args:
            inputs: [batch_size, input_dim, sourceL]
        """
        batch_size = inputs.size(0)
        input_dim = inputs.size(1)
        sourceL = inputs.size(2)

        # repeat embeddings across batch_size
        # result is [batch_size x input_dim x embedding_dim]
        embedding = self.embedding.repeat(batch_size, 1, 1)  
        embedded_inputs = []
        # result is [batch_size, 1, input_dim, sourceL] 
        ips = inputs.unsqueeze(1)
        
        for i in range(sourceL):
            # [batch_size x 1 x input_dim] * [batch_size x input_dim x embedding_dim]
            # result is [batch_size, embedding_dim]
            embedded_inputs.append(torch.bmm(
                ips[:, :, :, i].float(),
                embedding).squeeze(1))

        # Result is [sourceL x batch_size x embedding_dim]
        embedded_inputs = torch.cat(embedded_inputs).view(
                sourceL,
                batch_size,
                embedding.size(2))

        # query the actor net for the input indices 
        # making up the output, and the pointer attn 
        probs_, action_idxs = self.actor_net(embedded_inputs, hidden_logits)
       
        # Select the actions (inputs pointed to 
        # by the pointer net) and the corresponding
        # logits
        # should be size [batch_size x 
        actions = []
        # inputs is [batch_size, input_dim, sourceL]
        inputs_ = inputs.transpose(1, 2)
        # inputs_ is [batch_size, sourceL, input_dim]
        for action_id in action_idxs:
            actions.append(inputs_[[x for x in range(batch_size)], action_id.data, :])

        if self.is_train:
            # probs_ is a list of len sourceL of [batch_size x sourceL]
            probs = []
            for prob, action_id in zip(probs_, action_idxs):
                probs.append(prob[[x for x in range(batch_size)], action_id.data])
        else:
            # return the list of len sourceL of [batch_size x sourceL]
            probs = probs_

        # get the critic value fn estimates for the baseline
        # [batch_size]
        #v = self.critic_net(embedded_inputs)
    
        # [batch_size]
        R, C = self.objective_fn(actions, self.use_cuda)
        
        #return R, v, probs, actions, action_idxs
        return R, C, probs, actions, action_idxs

# %% [markdown]
# ## Minus reward

# %%
def reward_constraint(sample_solution, USE_CUDA=False):
    """
    Args:
        List of length sourceL of [batch_size] Tensors
    Returns:
        Tensor of shape [batch_size] containins rewards
    """
    batch_size = sample_solution[0].size(0)
    n = len(sample_solution)
    tour_len = Variable(torch.zeros([batch_size]))
    constraints = Variable(torch.zeros([batch_size]))
    left = Variable(torch.zeros([batch_size]))
    right = Variable(torch.zeros([batch_size]))
    sample_solution = torch.stack(sample_solution)
    
    #print(sample_solution.size())
    
    right_corner, right_index = torch.max(torch.norm(sample_solution, dim=2), dim=0)

    
    
    if USE_CUDA:
        tour_len = tour_len.cuda()
        constraints = constraints.cuda()
        left = left.cuda()
        right = right.cuda()
    
    for i in range(n-1):
        tour_len += torch.norm(sample_solution[i] - sample_solution[i+1], dim=1)
    
    tour_len += torch.norm(sample_solution[n-1] - sample_solution[0], dim=1)
    
    for i in range(int(n/2)):
        left += torch.norm(sample_solution[i], dim=1)
        
    for i in range(int(n/2), n-1):
        right += torch.norm(sample_solution[i], dim=1)
        
    
    constraints += F.relu(left-right)
    
    tour_len += constraints

    return tour_len, constraints

# %%
def reward(sample_solution, USE_CUDA=False):
    """
    Args:
        List of length sourceL of [batch_size] Tensors
    Returns:
        Tensor of shape [batch_size] containins rewards
    """
    batch_size = sample_solution[0].size(0)
    n = len(sample_solution)
    tour_len = Variable(torch.zeros([batch_size]))
    constraints = Variable(torch.zeros([batch_size]))
    left = Variable(torch.zeros([batch_size]))
    right = Variable(torch.zeros([batch_size]))
    sample_solution = torch.stack(sample_solution)
    
    #print(sample_solution.size())
    
    right_corner, right_index = torch.max(torch.norm(sample_solution, dim=2), dim=0)

    
    
    if USE_CUDA:
        tour_len = tour_len.cuda()
        constraints = constraints.cuda()
        left = left.cuda()
        right = right.cuda()
    
    for i in range(n-1):
        tour_len += torch.norm(sample_solution[i] - sample_solution[i+1], dim=1)
    
    tour_len += torch.norm(sample_solution[n-1] - sample_solution[0], dim=1)
    
    for i in range(int(n/2)):
        left += torch.norm(sample_solution[i], dim=1)
        
    for i in range(int(n/2), n-1):
        right += torch.norm(sample_solution[i], dim=1)
        
    
    constraints += F.relu(left-right)


    return tour_len, constraints

# %%
def constraint(sample_solution, USE_CUDA=False):
    """
    Args:
        List of length sourceL of [batch_size] Tensors
    Returns:
        Tensor of shape [batch_size] containins rewards
    """
    batch_size = sample_solution[0].size(0)
    n = len(sample_solution)
    tour_len = Variable(torch.zeros([batch_size]))
    constraints = Variable(torch.zeros([batch_size]))
    left = Variable(torch.zeros([batch_size]))
    right = Variable(torch.zeros([batch_size]))
    sample_solution = torch.stack(sample_solution)
    
    #print(sample_solution.size())
    
    right_corner, right_index = torch.max(torch.norm(sample_solution, dim=2), dim=0)

    
    
    if USE_CUDA:
        tour_len = tour_len.cuda()
        constraints = constraints.cuda()
        left = left.cuda()
        right = right.cuda()
    
    for i in range(int(n/2)):
        left += torch.norm(sample_solution[i], dim=1)
        
    for i in range(int(n/2), n-1):
        right += torch.norm(sample_solution[i], dim=1)
        
    
    constraints += left-right
    
    tour_len += constraints

    return tour_len, constraints

# %% [markdown]
# # Training

# %% [markdown]
# ## Original

# %%
import os
from tqdm import tqdm

import pprint as pp
import numpy as np

import torch
print(torch.__version__)
import torch.optim as optim
import torch.autograd as autograd
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from tqdm import tqdm_notebook
# Out:
# 1.0.1.post2

# %%
input_dim = 2
embedding_dim = 128
hidden_dim = 128
max_decoding_len = 50
terminating_symbol = ''
n_glimpses = 1
n_process_block_iters = 3
tanh_exploration = 10
use_tanh = True
beam_size = 1
objective_fn = reward_constraint
is_train = True
use_cuda = True

# %%
# build model
model = NeuralCombOptRL(input_dim, embedding_dim, hidden_dim,
                        max_decoding_len, terminating_symbol,
                        n_glimpses, n_process_block_iters, 
                        tanh_exploration, use_tanh, beam_size,
                        objective_fn, is_train, use_cuda)

# %%
# the critic baseline
critic_exp_mvg_avg = torch.zeros(1)
beta = 0.8

if use_cuda:
    model = model.cuda()
    #critic_mse = critic_mse.cuda()
    critic_exp_mvg_avg = critic_exp_mvg_avg.cuda()

# %%
# The low learning rate doesn't work
actor_net_lr = 1e-3
critic_net_lr = 1e-3
actor_lr_decay_step = 5000
critic_lr_decay_step = 5000
actor_lr_decay_rate = 0.96
actor_lr_decay_rate = 0.96

# %%
#critic_mse = torch.nn.MSELoss()
#critic_optim = optim.Adam(model.critic_net.parameters(), lr=float(args['critic_net_lr']))
actor_optim = optim.Adam(model.actor_net.parameters(), lr=actor_net_lr)

actor_scheduler = lr_scheduler.MultiStepLR(actor_optim,
        range(actor_lr_decay_step, actor_lr_decay_step * 1000,actor_lr_decay_step),
                                           gamma=actor_lr_decay_rate)

#critic_scheduler = lr_scheduler.MultiStepLR(critic_optim,
#        range(int(args['critic_lr_decay_step']), int(args['critic_lr_decay_step']) * 1000,
#            int(args['critic_lr_decay_step'])), gamma=float(args['critic_lr_decay_rate']))

# %%
step = 0
log_step = 50
epoch = 0
n_epoch = 1
R_mean = []
R_std = []
C_mean = []
for i in range(epoch, epoch + n_epoch):

    # put in train mode!
    model.train()
    model.actor_net.decoder.decode_type = "stochastic"
    # sample_batch is [batch_size x input_dim x sourceL]
    for batch_id, sample_batch in enumerate(train_dataloader):
        
        model.train()
        model.actor_net.decoder.decode_type = "stochastic"
    
        bat = Variable(sample_batch)
        if use_cuda:
            bat = bat.cuda()

        R, C, probs, actions, actions_idxs, hidden_logits = model(bat)
        
        if batch_id == 0:
            critic_exp_mvg_avg = R.mean()
        else:
            # update critic baseline
            critic_exp_mvg_avg = (critic_exp_mvg_avg * beta) + ((1. - beta) * R.mean())

        advantage = R - critic_exp_mvg_avg

        # log probability
        logprobs = 0
        nll = 0
        entropy = 0
        # the size of probs (50 * batchsize)
        for prob in probs: 
            # compute the sum of the log probability
            # for each tour in the batch
            logprob = torch.log(prob)
            nll += -logprob
            logprobs += logprob

        # guard against nan
        nll[(nll != nll).detach()] = 0.
        # clamp any -inf's to 0 to throw away this tour
        logprobs[(logprobs < -1000).detach()] = 0.

        # multiply each time step by the advantage
        # advantage = Reward-Critic
        # reinforce = (R-b)*log(p)
        # R-b does not have gradient
        # gradient = (R-b)*d log(p)       
        
        reinforce = advantage * logprobs
        actor_loss = reinforce.mean()

        actor_optim.zero_grad()

        actor_loss.backward()

        max_grad_norm = 1.0
        # clip gradient norms
        # to avoid too large gradient
        torch.nn.utils.clip_grad_norm_(model.actor_net.parameters(),
                                       max_grad_norm, norm_type=2)

        actor_optim.step()
        actor_scheduler.step()

        critic_exp_mvg_avg = critic_exp_mvg_avg.detach()

        #critic_scheduler.step()

        #R = R.detach()
        #critic_loss = critic_mse(v.squeeze(1), R)
        #critic_optim.zero_grad()
        #critic_loss.backward()
        
        #torch.nn.utils.clip_grad_norm_(model.critic_net.parameters(),
        #        float(args['max_grad_norm']), norm_type=2)

        #critic_optim.step()
        
        step += 1

        if step % log_step == 0:
            print('epoch: {}, train_batch_id: {}, avg_reward: {}'.format(
                i, batch_id, (R-C).mean().item()))
            print('avg_penalty', C.mean().item())
            example_output = []
            example_input = []
            for idx, action in enumerate(actions):
                example_output.append(actions_idxs[idx][0].item())
                example_input.append(sample_batch[0, :, idx][0])
            # print('Example train input: {}'.format(example_input))
            print('Example train output: {}'.format(example_output))
            R_mean.append((R-C).mean().item())
            R_std.append((R-C).std().item())
            C_mean.append(C.mean().item())
        
        if batch_id % 500 == 0:     
            # validation
            avg_reward = []
            avg_constraint = []
            val_step = 0
            model.eval()
            model.actor_net.decoder.decode_type = "greedy"
            
            for batch_id, val_batch in enumerate(val_dataloader):
                bat = Variable(val_batch)
            
                if use_cuda:
                    bat = bat.cuda()
            
                R, C, probs, actions, action_idxs,_ = model(bat)
                avg_constraint.append(C.mean().cpu().numpy())
                avg_reward.append((R-C).mean().cpu().numpy())
                val_step += 1.
            print('#####################################')
            print('Validation overall avg_reward: {}'.format(np.mean(avg_reward)))
            print('Validation overall reward var: {}'.format(np.var(avg_reward)))
            print('Validation overall avg_constraint: {}'.format(np.mean(avg_constraint)))
            print('Validation overall constraint var: {}'.format(np.var(avg_constraint)))
            print('#####################################')
# Out:
# #####################################
# Validation overall avg_reward: 19.74380111694336
# Validation overall reward var: 0.043156616389751434
# Validation overall avg_constraint: 0.0
# Validation overall constraint var: 0.0
# #####################################
# epoch: 0, train_batch_id: 49, avg_reward: 18.13925552368164
# avg_penalty 0.0
# Example train output: [4, 46, 16, 13, 26, 21, 40, 14, 0, 44, 31, 49, 37, 30, 8, 9, 19, 29, 20, 15, 28, 24, 5, 47, 2, 43, 1, 12, 42, 18, 27, 17, 23, 22, 25, 34, 32, 35, 3, 36, 48, 6, 33, 39, 38, 41, 10, 7, 45, 11]
# epoch: 0, train_batch_id: 99, avg_reward: 17.562271118164062
# avg_penalty 0.0
# Example train output: [27, 16, 2, 8, 32, 30, 35, 31, 43, 23, 4, 38, 37, 49, 10, 25, 17, 36, 22, 18, 48, 11, 13, 15, 7, 41, 24, 19, 26, 47, 3, 34, 1, 0, 20, 14, 46, 44, 21, 45, 40, 9, 28, 42, 33, 39, 12, 6, 5, 29]
# epoch: 0, train_batch_id: 149, avg_reward: 18.147733688354492
# avg_penalty 0.0
# Example train output: [10, 16, 42, 7, 30, 2, 37, 47, 5, 46, 11, 28, 19, 15, 4, 23, 21, 8, 44, 32, 45, 33, 25, 34, 12, 20, 17, 9, 38, 48, 31, 24, 6, 39, 14, 18, 49, 41, 0, 13, 29, 22, 40, 3, 36, 43, 35, 1, 27, 26]
# epoch: 0, train_batch_id: 199, avg_reward: 17.44068145751953
# avg_penalty 0.0
# Example train output: [24, 42, 2, 30, 18, 6, 14, 28, 36, 4, 44, 20, 5, 0, 23, 26, 19, 41, 39, 38, 16, 13, 33, 7, 8, 40, 48, 1, 15, 12, 43, 17, 49, 9, 47, 45, 35, 32, 46, 31, 29, 25, 27, 34, 21, 22, 10, 11, 37, 3]
# epoch: 0, train_batch_id: 249, avg_reward: 17.205810546875
# avg_penalty 0.0
# Example train output: [13, 15, 49, 6, 44, 11, 41, 32, 20, 9, 28, 48, 17, 37, 40, 34, 22, 23, 14, 47, 43, 39, 2, 19, 33, 24, 3, 8, 45, 16, 0, 38, 25, 27, 12, 29, 18, 7, 42, 31, 30, 10, 5, 35, 46, 26, 4, 36, 1, 21]
# epoch: 0, train_batch_id: 299, avg_reward: 17.243377685546875
# avg_penalty 0.0
# Example train output: [25, 12, 11, 32, 9, 17, 7, 4, 49, 28, 42, 5, 27, 20, 3, 26, 40, 15, 38, 48, 35, 34, 44, 19, 31, 24, 2, 36, 46, 33, 18, 47, 0, 21, 41, 14, 37, 10, 30, 43, 29, 45, 23, 13, 39, 6, 22, 1, 8, 16]
# epoch: 0, train_batch_id: 349, avg_reward: 17.85013198852539
# avg_penalty 0.0
# epoch: 0, train_batch_id: 14999, avg_reward: 11.101119995117188
# avg_penalty 0.0
# Example train output: [30, 4, 24, 9, 3, 12, 2, 15, 43, 21, 18, 28, 38, 47, 36, 26, 6, 49, 34, 5, 14, 40, 41, 44, 33, 0, 8, 13, 20, 39, 29, 23, 31, 22, 10, 48, 46, 42, 11, 37, 35, 16, 32, 7, 19, 1, 25, 17, 27, 45]

# %%
step = 0
log_step = 50
epoch = 0
n_epoch = 1
R_mean = []
R_std = []
C_mean = []
for i in range(epoch, epoch + n_epoch):

    # put in train mode!
    model.train()
    model.actor_net.decoder.decode_type = "stochastic"
    # sample_batch is [batch_size x input_dim x sourceL]
    for batch_id, sample_batch in enumerate(train_dataloader):
        
        model.train()
        model.actor_net.decoder.decode_type = "stochastic"
    
        bat = Variable(sample_batch)
        if use_cuda:
            bat = bat.cuda()

        R, C, probs, actions, actions_idxs, hidden_logits = model(bat)
        
        if batch_id == 0:
            critic_exp_mvg_avg = R.mean()
        else:
            # update critic baseline
            critic_exp_mvg_avg = (critic_exp_mvg_avg * beta) + ((1. - beta) * R.mean())

        advantage = R - critic_exp_mvg_avg

        # log probability
        logprobs = 0
        nll = 0
        entropy = 0
        # the size of probs (50 * batchsize)
        for prob in probs: 
            # compute the sum of the log probability
            # for each tour in the batch
            logprob = torch.log(prob)
            nll += -logprob
            logprobs += logprob

        # guard against nan
        nll[(nll != nll).detach()] = 0.
        # clamp any -inf's to 0 to throw away this tour
        logprobs[(logprobs < -1000).detach()] = 0.

        # multiply each time step by the advantage
        # advantage = Reward-Critic
        # reinforce = (R-b)*log(p)
        # R-b does not have gradient
        # gradient = (R-b)*d log(p)       
        
        reinforce = advantage * logprobs
        actor_loss = reinforce.mean()

        actor_optim.zero_grad()

        actor_loss.backward()

        max_grad_norm = 1.0
        # clip gradient norms
        # to avoid too large gradient
        torch.nn.utils.clip_grad_norm_(model.actor_net.parameters(),
                                       max_grad_norm, norm_type=2)

        actor_optim.step()
        actor_scheduler.step()

        critic_exp_mvg_avg = critic_exp_mvg_avg.detach()

        #critic_scheduler.step()

        #R = R.detach()
        #critic_loss = critic_mse(v.squeeze(1), R)
        #critic_optim.zero_grad()
        #critic_loss.backward()
        
        #torch.nn.utils.clip_grad_norm_(model.critic_net.parameters(),
        #        float(args['max_grad_norm']), norm_type=2)

        #critic_optim.step()
        
        step += 1

        if step % log_step == 0:
            print('epoch: {}, train_batch_id: {}, avg_reward: {}'.format(
                i, batch_id, (R-C).mean().item()))
            print('avg_penalty', C.mean().item())
            example_output = []
            example_input = []
            for idx, action in enumerate(actions):
                example_output.append(actions_idxs[idx][0].item())
                example_input.append(sample_batch[0, :, idx][0])
            # print('Example train input: {}'.format(example_input))
            print('Example train output: {}'.format(example_output))
            R_mean.append((R-C).mean().item())
            R_std.append((R-C).std().item())
            C_mean.append(C.mean().item())
        '''
        if batch_id % 500 == 0:     
            # validation
            avg_reward = []
            avg_constraint = []
            val_step = 0
            model.eval()
            model.actor_net.decoder.decode_type = "greedy"
            
            for batch_id, val_batch in enumerate(val_dataloader):
                bat = Variable(val_batch)
            
                if use_cuda:
                    bat = bat.cuda()
            
                R, C, probs, actions, action_idxs,_ = model(bat)
                avg_constraint.append(C.mean().cpu().numpy())
                avg_reward.append((R-C).mean().cpu().numpy())
                val_step += 1.
            print('#####################################')
            print('Validation overall avg_reward: {}'.format(np.mean(avg_reward)))
            print('Validation overall reward var: {}'.format(np.var(avg_reward)))
            print('Validation overall avg_constraint: {}'.format(np.mean(avg_constraint)))
            print('Validation overall constraint var: {}'.format(np.var(avg_constraint)))
            print('#####################################')
        '''
# Out:
# epoch: 0, train_batch_id: 49, avg_reward: 18.004884719848633
# avg_penalty 0.0
# Example train output: [6, 49, 22, 3, 32, 43, 39, 1, 26, 14, 5, 28, 34, 36, 41, 42, 30, 19, 2, 47, 16, 18, 24, 0, 45, 48, 4, 25, 17, 35, 29, 44, 13, 15, 8, 27, 12, 38, 20, 33, 46, 23, 9, 11, 37, 7, 31, 21, 40, 10]
# epoch: 0, train_batch_id: 99, avg_reward: 17.99312973022461
# avg_penalty 0.0
# Example train output: [12, 21, 16, 30, 24, 27, 25, 22, 47, 38, 43, 39, 6, 45, 19, 35, 49, 2, 40, 10, 34, 29, 41, 18, 4, 11, 0, 44, 14, 9, 23, 15, 48, 32, 42, 31, 37, 13, 36, 46, 17, 8, 7, 26, 1, 3, 28, 5, 20, 33]
# epoch: 0, train_batch_id: 149, avg_reward: 17.791805267333984
# avg_penalty 0.0
# Example train output: [34, 45, 36, 38, 8, 42, 37, 31, 16, 12, 19, 39, 32, 0, 26, 18, 35, 24, 46, 1, 27, 49, 6, 14, 40, 28, 21, 30, 10, 7, 11, 22, 9, 29, 23, 20, 15, 48, 43, 44, 13, 25, 41, 33, 17, 5, 47, 4, 2, 3]
# epoch: 0, train_batch_id: 199, avg_reward: 17.468204498291016
# avg_penalty 0.0
# Example train output: [28, 24, 20, 43, 42, 37, 30, 4, 0, 15, 49, 40, 10, 41, 8, 38, 34, 9, 12, 36, 48, 26, 11, 31, 33, 46, 44, 1, 25, 32, 2, 17, 27, 21, 5, 18, 45, 19, 3, 16, 23, 13, 39, 6, 47, 7, 35, 22, 29, 14]
# epoch: 0, train_batch_id: 249, avg_reward: 17.293352127075195
# avg_penalty 0.0
# Example train output: [32, 42, 47, 25, 17, 27, 24, 44, 38, 41, 5, 33, 2, 7, 12, 43, 13, 6, 20, 36, 28, 23, 14, 35, 8, 1, 31, 11, 0, 49, 9, 4, 46, 19, 10, 26, 18, 3, 40, 29, 45, 21, 39, 30, 16, 34, 37, 22, 48, 15]
# epoch: 0, train_batch_id: 299, avg_reward: 17.305023193359375
# avg_penalty 0.0
# Example train output: [49, 10, 36, 38, 39, 17, 37, 48, 14, 42, 4, 35, 13, 28, 24, 45, 18, 27, 15, 0, 7, 41, 12, 6, 32, 19, 30, 20, 22, 1, 47, 40, 8, 23, 46, 9, 11, 34, 43, 26, 2, 16, 33, 3, 5, 31, 44, 29, 21, 25]
# epoch: 0, train_batch_id: 14699, avg_reward: 11.295319557189941
# avg_penalty 0.0
# Example train output: [0, 12, 45, 49, 41, 1, 7, 9, 18, 39, 29, 40, 10, 35, 23, 47, 20, 48, 17, 38, 13, 44, 31, 21, 8, 2, 36, 16, 4, 42, 28, 46, 11, 34, 43, 27, 26, 14, 33, 32, 5, 22, 3, 37, 25, 24, 30, 15, 19, 6]
# epoch: 0, train_batch_id: 14749, avg_reward: 11.182418823242188
# avg_penalty 0.0
# Example train output: [11, 3, 22, 35, 30, 10, 34, 5, 15, 45, 36, 21, 0, 42, 47, 19, 44, 17, 33, 7, 46, 49, 48, 37, 24, 32, 31, 1, 9, 14, 20, 41, 18, 16, 23, 43, 39, 28, 38, 4, 8, 40, 6, 27, 29, 13, 2, 12, 25, 26]
# epoch: 0, train_batch_id: 14799, avg_reward: 10.901883125305176
# avg_penalty 0.0
# Example train output: [10, 46, 7, 30, 14, 38, 28, 49, 1, 35, 39, 36, 0, 41, 4, 32, 42, 31, 27, 23, 2, 6, 24, 9, 34, 15, 22, 12, 18, 3, 11, 37, 21, 13, 33, 43, 25, 40, 16, 26, 19, 44, 5, 20, 45, 17, 8, 47, 29, 48]
# epoch: 0, train_batch_id: 14849, avg_reward: 11.017998695373535
# avg_penalty 0.0007458627223968506
# Example train output: [8, 34, 6, 16, 14, 33, 4, 44, 28, 47, 26, 7, 23, 42, 29, 43, 38, 18, 39, 40, 20, 12, 9, 2, 49, 15, 24, 1, 21, 3, 10, 17, 45, 31, 30, 32, 36, 48, 5, 37, 19, 41, 11, 13, 22, 35, 27, 0, 46, 25]
# epoch: 0, train_batch_id: 14899, avg_reward: 10.953807830810547
# avg_penalty 0.00014992058277130127
# Example train output: [48, 35, 44, 6, 40, 5, 39, 11, 3, 4, 2, 46, 7, 32, 27, 13, 14, 36, 28, 33, 29, 18, 41, 25, 17, 1, 16, 22, 15, 26, 31, 24, 21, 49, 9, 45, 30, 34, 42, 38, 43, 10, 23, 19, 47, 37, 20, 12, 0, 8]
# epoch: 0, train_batch_id: 14949, avg_reward: 11.026825904846191
# avg_penalty 0.0
# Example train output: [5, 4, 9, 45, 46, 27, 41, 39, 26, 34, 25, 38, 24, 42, 33, 2, 0, 19, 37, 40, 44, 17, 1, 36, 35, 7, 13, 30, 32, 14, 29, 12, 43, 6, 15, 11, 28, 20, 22, 49, 18, 47, 8, 16, 10, 23, 31, 48, 21, 3]
# epoch: 0, train_batch_id: 14999, avg_reward: 10.949670791625977
# avg_penalty 0.00042384862899780273
# Example train output: [45, 49, 35, 30, 28, 29, 6, 12, 11, 42, 44, 48, 27, 10, 16, 26, 7, 38, 43, 13, 2, 39, 33, 3, 41, 40, 31, 14, 5, 37, 1, 9, 23, 32, 17, 21, 15, 18, 22, 46, 36, 4, 20, 8, 34, 25, 0, 24, 47, 19]

# %%
R_mean = np.array(R_mean)
R_std = np.array(R_std)
print(R_mean.shape)
k = np.arange(0, 50*R_mean.shape[0], 50)
plt.plot(k, R_mean)
plt.fill_between(k, R_mean-R_std, R_mean+R_std, alpha=0.15)
plt.show()
# Out:
# (300,)

# %%
C_mean = np.array(C_mean)
print(C_mean.shape)
k = np.arange(0, 50*C_mean.shape[0], 50)
plt.plot(k, C_mean)
plt.show()
# Out:
# (300,)

# %%
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_mean_orig.npy', R_mean)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_std_orig.npy', R_std)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/C_mean_orig.npy', C_mean)

# %%
torch.save(model,'drive/My Drive/HRL-CO/model/CornerConstraint/model_orig.pt')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type NeuralCombOptRL. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type PointerNetwork. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Decoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
R_mean = np.array(R_mean)
R_std = np.array(R_std)
print(R_mean.shape)
k = np.arange(0, 50*R_mean.shape[0], 50)
plt.plot(k, R_mean)
plt.fill_between(k, R_mean-R_std, R_mean+R_std, alpha=0.15)
plt.show()
# Out:
# (300,)

# %%
C_mean = np.array(C_mean)
print(C_mean.shape)
k = np.arange(0, 50*C_mean.shape[0], 50)
plt.plot(k, C_mean)
plt.show()
# Out:
# (300,)

# %%
torch.save(model,'drive/My Drive/HRL-CO/model/CornerConstraint/model_original.pt')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type NeuralCombOptRL. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type PointerNetwork. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Decoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_mean_original.npy', R_mean)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_std_original.npy', R_std)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/C_mean_original.npy', C_mean)

# %%
R_mean_test = np.load('drive/My Drive/HRL-CO/model/CornerConstraint/R_mean_original.npy')
R_std_test = np.load('drive/My Drive/HRL-CO/model/CornerConstraint/R_std_original.npy')

# %% [markdown]
# ## Hierarchical

# %%
input_dim = 2
embedding_dim = 128
hidden_dim = 128
max_decoding_len = 50
terminating_symbol = ''
n_glimpses = 1
n_process_block_iters = 3
tanh_exploration = 10
use_tanh = True
beam_size = 1
objective_fn = constraint
is_train = True
use_cuda = True

# %%
# build model
model_low = NeuralCombOptRL(input_dim, embedding_dim, hidden_dim,
                        max_decoding_len, terminating_symbol,
                        n_glimpses, n_process_block_iters, 
                        tanh_exploration, use_tanh, beam_size,
                        objective_fn, is_train, use_cuda)

# %%
# the critic baseline
critic_exp_mvg_avg = torch.zeros(1)
beta = 0.8

if use_cuda:
    model_low = model_low.cuda()
    #critic_mse = critic_mse.cuda()
    critic_exp_mvg_avg = critic_exp_mvg_avg.cuda()

# %%
# The low learning rate doesn't work
actor_net_lr = 1e-3
critic_net_lr = 1e-3
actor_lr_decay_step = 5000
critic_lr_decay_step = 5000
actor_lr_decay_rate = 0.96
actor_lr_decay_rate = 0.96

# %%
#critic_mse = torch.nn.MSELoss()
#critic_optim = optim.Adam(model.critic_net.parameters(), lr=float(args['critic_net_lr']))
actor_optim = optim.Adam(model_low.actor_net.parameters(), lr=actor_net_lr)

actor_scheduler = lr_scheduler.MultiStepLR(actor_optim,
        range(actor_lr_decay_step, actor_lr_decay_step * 1000,actor_lr_decay_step),
                                           gamma=actor_lr_decay_rate)

#critic_scheduler = lr_scheduler.MultiStepLR(critic_optim,
#        range(int(args['critic_lr_decay_step']), int(args['critic_lr_decay_step']) * 1000,
#            int(args['critic_lr_decay_step'])), gamma=float(args['critic_lr_decay_rate']))

# %%
step = 0
log_step = 10
epoch = 0
n_epoch = 1
R_low = []
for i in range(epoch, epoch + n_epoch):

    # put in train mode!
    model_low.train()
    model_low.actor_net.decoder.decode_type = "stochastic"
    # sample_batch is [batch_size x input_dim x sourceL]
    for batch_id, sample_batch in enumerate(train_dataloader):
        
        model_low.train()
        model_low.actor_net.decoder.decode_type = "stochastic"
    
        bat = Variable(sample_batch)
        if use_cuda:
            bat = bat.cuda()

        R, C, probs, actions, actions_idxs, hidden_logits = model_low(bat)
        
        if batch_id == 0:
            critic_exp_mvg_avg = R.mean()
        else:
            # update critic baseline
            critic_exp_mvg_avg = (critic_exp_mvg_avg * beta) + ((1. - beta) * R.mean())

        advantage = R - critic_exp_mvg_avg

        # log probability
        logprobs = 0
        nll = 0
        entropy = 0
        # the size of probs (50 * batchsize)
        for prob in probs: 
            # compute the sum of the log probability
            # for each tour in the batch
            logprob = torch.log(prob)
            nll += -logprob
            logprobs += logprob

        # guard against nan
        nll[(nll != nll).detach()] = 0.
        # clamp any -inf's to 0 to throw away this tour
        logprobs[(logprobs < -1000).detach()] = 0.

        # multiply each time step by the advantage
        # advantage = Reward-Critic
        # reinforce = (R-b)*log(p)
        # R-b does not have gradient
        # gradient = (R-b)*d log(p)       
        
        reinforce = advantage * logprobs
        actor_loss = reinforce.mean()

        actor_optim.zero_grad()

        actor_loss.backward()

        max_grad_norm = 1.0
        # clip gradient norms
        # to avoid too large gradient
        torch.nn.utils.clip_grad_norm_(model.actor_net.parameters(),
                                       max_grad_norm, norm_type=2)

        actor_optim.step()
        actor_scheduler.step()

        critic_exp_mvg_avg = critic_exp_mvg_avg.detach()

        #critic_scheduler.step()

        #R = R.detach()
        #critic_loss = critic_mse(v.squeeze(1), R)
        #critic_optim.zero_grad()
        #critic_loss.backward()
        
        #torch.nn.utils.clip_grad_norm_(model.critic_net.parameters(),
        #        float(args['max_grad_norm']), norm_type=2)

        #critic_optim.step()
        
        step += 1

        if step % log_step == 0:
            print('epoch: {}, train_batch_id: {}, avg_reward: {}'.format(
                i, batch_id, (R-C).mean().item()))
            print('avg_penalty', C.mean().item())
            example_output = []
            example_input = []
            for idx, action in enumerate(actions):
                example_output.append(actions_idxs[idx][0].item())
                example_input.append(sample_batch[0, :, idx][0])
            # print('Example train input: {}'.format(example_input))
            print('Example train output: {}'.format(example_output))
            R_low.append((R-C).mean().item())
        '''
        if batch_id == 6000:
            torch.save(model, 'drive/My Drive/HRL-CO/model/TSP50-0331-low-6000.pt')
        if batch_id == 8000:
            torch.save(model, 'drive/My Drive/HRL-CO/model/TSP50-0331-low-8000.pt')
        if batch_id == 10000:
            torch.save(model, 'drive/My Drive/HRL-CO/model/TSP50-0331-low-10000.pt')
        if batch_id == 12000:
            torch.save(model, 'drive/My Drive/HRL-CO/model/TSP50-0331-low-12000.pt')
        '''
        
        if batch_id % 500 == 0:     
            # validation
            avg_reward = []
            avg_constraint = []
            val_step = 0
            model.eval()
            model.actor_net.decoder.decode_type = "greedy"
            
            for batch_id, val_batch in enumerate(val_dataloader):
                bat = Variable(val_batch)
            
                if use_cuda:
                    bat = bat.cuda()
            
                R, C, probs, actions, action_idxs,_ = model(bat)
                avg_constraint.append(C.mean().cpu().numpy())
                avg_reward.append((R-C).mean().cpu().numpy())
                val_step += 1.
            print('#####################################')
            print('Validation overall avg_reward: {}'.format(np.mean(avg_reward)))
            print('Validation overall reward var: {}'.format(np.var(avg_reward)))
            print('Validation overall avg_constraint: {}'.format(np.mean(avg_constraint)))
            print('Validation overall constraint var: {}'.format(np.var(avg_constraint)))
            print('#####################################')
# Out:
# #####################################
# Validation overall avg_reward: 10.739726066589355
# Validation overall reward var: 0.016217384487390518
# Validation overall avg_constraint: 0.0
# Validation overall constraint var: 0.0
# #####################################
# epoch: 0, train_batch_id: 9, avg_reward: 0.0
# avg_penalty -2.7057039737701416
# Example train output: [22, 2, 8, 19, 18, 27, 6, 10, 47, 12, 1, 3, 30, 23, 7, 46, 37, 32, 16, 11, 49, 36, 5, 41, 24, 20, 33, 28, 0, 29, 35, 15, 4, 9, 14, 42, 13, 43, 17, 45, 31, 25, 34, 21, 40, 38, 48, 44, 39, 26]
# epoch: 0, train_batch_id: 19, avg_reward: 0.0
# avg_penalty -6.898642063140869
# Example train output: [12, 1, 7, 6, 0, 5, 19, 3, 18, 27, 16, 26, 30, 22, 17, 29, 41, 49, 14, 28, 20, 25, 31, 33, 34, 4, 13, 35, 40, 2, 11, 23, 43, 47, 32, 10, 42, 39, 21, 8, 24, 44, 45, 9, 36, 46, 15, 37, 38, 48]
# epoch: 0, train_batch_id: 29, avg_reward: 0.0
# avg_penalty -8.967554092407227
# Example train output: [39, 46, 15, 0, 32, 33, 25, 24, 44, 14, 17, 5, 26, 22, 43, 40, 28, 4, 48, 35, 29, 7, 49, 34, 30, 3, 12, 11, 8, 2, 1, 41, 16, 6, 18, 9, 38, 47, 31, 27, 23, 20, 42, 13, 45, 10, 36, 37, 21, 19]
# epoch: 0, train_batch_id: 39, avg_reward: 0.0
# avg_penalty -9.612180709838867
# Example train output: [3, 30, 20, 46, 38, 43, 1, 25, 47, 49, 18, 6, 44, 2, 21, 9, 37, 45, 34, 0, 41, 8, 35, 11, 33, 4, 48, 16, 12, 31, 42, 39, 28, 17, 7, 40, 29, 27, 22, 36, 5, 10, 26, 24, 19, 15, 13, 32, 14, 23]
# epoch: 0, train_batch_id: 49, avg_reward: 0.0
# avg_penalty -9.526163101196289
# Example train output: [26, 30, 35, 48, 1, 43, 33, 32, 9, 6, 44, 40, 2, 45, 25, 21, 31, 12, 10, 47, 0, 36, 41, 28, 22, 37, 39, 17, 13, 46, 49, 27, 23, 19, 15, 3, 11, 24, 14, 29, 34, 7, 4, 8, 20, 42, 18, 38, 5, 16]
# epoch: 0, train_batch_id: 59, avg_reward: 0.0
# avg_penalty -9.537803649902344
# Example train output: [34, 10, 20, 31, 43, 36, 32, 0, 41, 22, 14, 46, 35, 39, 3, 15, 12, 16, 18, 8, 9, 37, 25, 38, 1, 45, 44, 19, 24, 27, 6, 48, 30, 11, 5, 23, 29, 49, 2, 40, 47, 17, 28, 21, 4, 33, 7, 42, 13, 26]
# epoch: 0, train_batch_id: 69, avg_reward: 0.0
# avg_penalty -9.555550575256348
# Example train output: [34, 29, 41, 36, 12, 18, 44, 39, 11, 47, 31, 6, 13, 21, 17, 27, 46, 30, 15, 28, 24, 1, 10, 49, 4, 32, 8, 22, 7, 45, 5, 3, 16, 40, 0, 37, 48, 2, 38, 19, 26, 35, 42, 25, 33, 20, 23, 14, 43, 9]
# epoch: 0, train_batch_id: 79, avg_reward: 0.0
# avg_penalty -9.4700288772583
# Example train output: [12, 16, 31, 4, 39, 23, 9, 24, 36, 43, 28, 40, 41, 8, 22, 29, 48, 19, 25, 37, 26, 5, 27, 6, 0, 13, 34, 38, 21, 46, 17, 1, 32, 10, 44, 2, 11, 7, 18, 20, 33, 15, 3, 30, 49, 47, 14, 45, 42, 35]
# epoch: 0, train_batch_id: 89, avg_reward: 0.0
# avg_penalty -9.438674926757812
# Example train output: [16, 48, 3, 37, 33, 20, 22, 42, 26, 1, 0, 39, 31, 9, 27, 19, 17, 36, 44, 7, 18, 43, 35, 30, 6, 2, 12, 8, 11, 32, 47, 46, 41, 29, 25, 45, 14, 34, 38, 5, 28, 23, 4, 10, 15, 49, 40, 13, 21, 24]
# epoch: 0, train_batch_id: 99, avg_reward: 0.0
# avg_penalty -9.54975700378418
# Example train output: [0, 10, 14, 19, 46, 39, 32, 45, 47, 4, 15, 24, 29, 34, 12, 20, 8, 7, 37, 3, 49, 9, 44, 27, 11, 31, 16, 42, 33, 30, 41, 5, 26, 36, 1, 18, 40, 13, 25, 6, 48, 28, 23, 38, 35, 21, 17, 2, 43, 22]

# %%
torch.save(model_low, 'drive/My Drive/HRL-CO/model/CornerConstraint/model_low.pt')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type NeuralCombOptRL. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type PointerNetwork. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Decoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
it = iter(val_dataloader)

# %%
x = next(it)

model_low.eval()
model_low.actor_net.decoder.decode_type = "stochastic"

R, C, probs, actions, actions_idxs, _ = model_low(x.cuda())
print("Reward:", R.mean().item())
print("Constraints:", C.mean().item())
# Out:
# Reward: -9.467669486999512
# Constraints: -9.467669486999512

# %%
test_coor = np.zeros([50,64,2])
test_idx = np.zeros([50,64])
for i in range(50):
    test_idx[i,:] = actions_idxs[i].cpu()
    test_coor[i,:] = actions[i].cpu()
    
test_graph = test_coor[:,0,:]
original_graph = x.numpy()[0,:,:]


plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
plt.scatter(original_graph[0], original_graph[1], marker='s')
plt.subplot(2,1,2)
plt.plot(test_graph[:25,0], test_graph[:25,1], marker='s')
plt.plot(test_graph[25:,0], test_graph[25:,1], marker='s')
# plt.plot([test_graph[-1,0],test_graph[0,0]], 
#         [test_graph[-1,1],test_graph[0,1]], marker='s')

# %% [markdown]
# ## Training High

# %%
model_low = torch.load('drive/My Drive/HRL-CO/model/CornerConstraint/model_low.pt')

# %%
input_dim = 2
embedding_dim = 128
hidden_dim = 128
max_decoding_len = 50
terminating_symbol = ''
n_glimpses = 1
n_process_block_iters = 3
tanh_exploration = 10
use_tanh = True
beam_size = 1
objective_fn = reward
is_train = True
use_cuda = True

# %%
# build model
model_high = NeuralCombOptRLHigh(input_dim, embedding_dim, hidden_dim,
                        max_decoding_len, terminating_symbol,
                        n_glimpses, n_process_block_iters, 
                        tanh_exploration, use_tanh, beam_size,
                        objective_fn, is_train, use_cuda)

# %%
# the critic baseline
critic_exp_mvg_avg = torch.zeros(1)
beta = 0.8

if use_cuda:
    model_high = model_high.cuda()
    model_low = model_low.cuda()
    #critic_mse = critic_mse.cuda()
    critic_exp_mvg_avg = critic_exp_mvg_avg.cuda()

# %%
# The low learning rate doesn't work
actor_net_lr = 1e-3
critic_net_lr = 1e-3
actor_lr_decay_step = 5000
critic_lr_decay_step = 5000
actor_lr_decay_rate = 0.96
actor_lr_decay_rate = 0.96

# %%
#critic_mse = torch.nn.MSELoss()
#critic_optim = optim.Adam(model.critic_net.parameters(), lr=float(args['critic_net_lr']))
actor_optim = optim.Adam(model_high.actor_net.parameters(), lr=actor_net_lr)

actor_scheduler = lr_scheduler.MultiStepLR(actor_optim,
        range(actor_lr_decay_step, actor_lr_decay_step * 1000,actor_lr_decay_step),
                                           gamma=actor_lr_decay_rate)

#critic_scheduler = lr_scheduler.MultiStepLR(critic_optim,
#        range(int(args['critic_lr_decay_step']), int(args['critic_lr_decay_step']) * 1000,
#            int(args['critic_lr_decay_step'])), gamma=float(args['critic_lr_decay_rate']))

# %%
step = 0
log_step = 50
epoch = 0
n_epoch = 1
R_mean_high = []
R_std_high = []
C_mean_high = []

for i in range(epoch, epoch + n_epoch):

    # put in train mode!
    model_high.train()
    model_low.eval()
    model_high.actor_net.decoder.decode_type = "stochastic"
    model_low.actor_net.decoder.decode_type = "stochastic"
    
    for batch_id, sample_batch in enumerate(train_dataloader):

        bat = Variable(sample_batch)
        if use_cuda:
            bat = bat.cuda()

        _, _, _, _, _, hidden_logits = model_low(bat)
        hidden_logits = torch.stack(hidden_logits).detach()

        R, C, probs, actions, actions_idxs = model_high(bat, hidden_logits)
        # the parameters can be trained
        # K = K*r
        
        if batch_id == 0:
            critic_exp_mvg_avg = R.mean()
        else:
            # update critic baseline
            critic_exp_mvg_avg = (critic_exp_mvg_avg * beta) + ((1. - beta) * R.mean())

        advantage = R - critic_exp_mvg_avg

        # log probability
        logprobs = 0
        nll = 0
        # the size of probs (50 * batchsize)
        for prob in probs: 
            # compute the sum of the log probability
            # for each tour in the batch
            logprob = torch.log(prob)
            nll += -logprob
            logprobs += logprob

        # guard against nan
        nll[(nll != nll).detach()] = 0.
        # clamp any -inf's to 0 to throw away this tour
        logprobs[(logprobs < -1000).detach()] = 0.   
        
        reinforce = advantage * logprobs
        actor_loss = reinforce.mean()

        actor_optim.zero_grad()

        actor_loss.backward()

        max_grad_norm = 1.0
        # clip gradient norms
        # to avoid too large gradient
        
        torch.nn.utils.clip_grad_norm_(model_high.actor_net.parameters(),
                                       max_grad_norm, norm_type=2)
        
        actor_optim.step()
        actor_scheduler.step()

        critic_exp_mvg_avg = critic_exp_mvg_avg.detach()

        #critic_scheduler.step()

        #R = R.detach()
        #critic_loss = critic_mse(v.squeeze(1), R)
        #critic_optim.zero_grad()
        #critic_loss.backward()
        
        #torch.nn.utils.clip_grad_norm_(model.critic_net.parameters(),
        #        float(args['max_grad_norm']), norm_type=2)

        #critic_optim.step()
        
        step += 1

        if step % log_step == 0:
            print('epoch: {}, train_batch_id: {}, avg_reward: {}'.format(
                i, batch_id, R.mean().item()))
            print('avg_constraints:', C.mean().item())
            '''
            example_output = []
            example_input = []
            for idx, action in enumerate(actions):
                example_output.append(actions_idxs[idx][0].item())
                example_input.append(sample_batch[0, :, idx][0])
            # print('Example train input: {}'.format(example_input))
            print('Example train output: {}'.format(example_output))
            '''
            R_mean_high.append(R.mean().item())
            R_std_high.append(R.std().item())
            C_mean_high.append(C.mean().item())
            
    '''
    # validation
    avg_reward = []
    val_step = 0
    model.eval()
    model.actor_net.decoder.decode_type = "greedy"
    
    for batch_id, val_batch in enumerate(tqdm_notebook(val_dataloader)):
        bat = Variable(val_batch)
    
        if use_cuda:
            bat = bat.cuda()
    
        R, probs, actions, action_idxs = model(bat)
        avg_reward.append(R.mean().cpu().numpy())
        val_step += 1.
    
    print('Validation overall avg_reward: {}'.format(np.mean(avg_reward)))
    print('Validation overall reward var: {}'.format(np.var(avg_reward)))
    
    # before next training loop
    model.actor_net.decoder.decode_type = "stochastic"
    # generate new data
    training_dataset = TSPDataset(train=True, size=size,
                                  num_samples=train_size)
    train_dataloader = DataLoader(training_dataset, batch_size=batch_size,
                                  shuffle=True, num_workers=1)
    
    '''
# Out:
# epoch: 0, train_batch_id: 49, avg_reward: 17.669837951660156
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 99, avg_reward: 17.637737274169922
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 149, avg_reward: 17.792682647705078
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 199, avg_reward: 17.712688446044922
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 249, avg_reward: 17.38747787475586
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 299, avg_reward: 17.753314971923828
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 349, avg_reward: 17.4403018951416
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 399, avg_reward: 17.62664031982422
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 449, avg_reward: 15.257558822631836
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 499, avg_reward: 12.794448852539062
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 549, avg_reward: 12.739587783813477
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 599, avg_reward: 12.846237182617188
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 649, avg_reward: 12.523616790771484
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 699, avg_reward: 12.516094207763672
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 749, avg_reward: 12.434691429138184
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 799, avg_reward: 12.318477630615234
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 849, avg_reward: 12.200923919677734
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 899, avg_reward: 12.22062873840332
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 949, avg_reward: 12.313691139221191
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 999, avg_reward: 12.076974868774414
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1049, avg_reward: 12.300024032592773
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1099, avg_reward: 12.151114463806152
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1149, avg_reward: 12.123526573181152
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1199, avg_reward: 12.509225845336914
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1249, avg_reward: 12.050216674804688
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1299, avg_reward: 11.994625091552734
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1349, avg_reward: 11.891683578491211
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1399, avg_reward: 11.906152725219727
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1449, avg_reward: 11.799480438232422
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1499, avg_reward: 11.743406295776367
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1549, avg_reward: 11.80295181274414
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1599, avg_reward: 11.675251007080078
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1649, avg_reward: 11.786446571350098
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1699, avg_reward: 11.695581436157227
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1749, avg_reward: 11.761168479919434
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 1799, avg_reward: 11.52603530883789
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 13899, avg_reward: 6.845150947570801
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 13949, avg_reward: 6.8567352294921875
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 13999, avg_reward: 6.8489789962768555
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14049, avg_reward: 6.891076564788818
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14099, avg_reward: 6.917016983032227
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14149, avg_reward: 6.7811784744262695
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14199, avg_reward: 6.784720420837402
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14249, avg_reward: 6.84946346282959
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14299, avg_reward: 6.801776885986328
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14349, avg_reward: 6.9170331954956055
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14399, avg_reward: 6.86942195892334
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14449, avg_reward: 6.806501388549805
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14499, avg_reward: 6.912290573120117
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14549, avg_reward: 6.831777572631836
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14599, avg_reward: 6.823008060455322
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14649, avg_reward: 6.795986175537109
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14699, avg_reward: 6.919388771057129
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14749, avg_reward: 6.8229475021362305
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14799, avg_reward: 6.8924560546875
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14849, avg_reward: 6.797631740570068
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14899, avg_reward: 6.859466552734375
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14949, avg_reward: 6.767887592315674
# avg_constraints: 0.0
# epoch: 0, train_batch_id: 14999, avg_reward: 6.851555824279785
# avg_constraints: 0.0

# %%
torch.save(model_high, 'drive/My Drive/HRL-CO/model/CornerConstraint/model_high.pt')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type NeuralCombOptRLHigh. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type PointerNetworkHigh. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type DecoderHigh. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_mean_high.npy', R_mean_high)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/R_std_high.npy', R_std_high)
np.save('drive/My Drive/HRL-CO/model/CornerConstraint/C_mean_high.npy', C_mean_high)

# %%
model_high = torch.load('drive/My Drive/HRL-CO/model/CornerConstraint/model_high.pt')

# %%
R_mean_high = np.load('drive/My Drive/HRL-CO/model/CornerConstraint/R_mean_high.npy')
R_std_high = np.load('drive/My Drive/HRL-CO/model/CornerConstraint/R_std_high.npy')
C_mean_high = np.load('drive/My Drive/HRL-CO/model/CornerConstraint/C_mean_high.npy')

# %%
R_mean_high = np.array(R_mean_high)
R_std_high = np.array(R_std_high)
print(R_mean_high.shape)
k = np.arange(0, 50*R_mean_high.shape[0], 50)
plt.plot(k, R_mean_high)
plt.fill_between(k, R_mean_high-R_std_high, R_mean_high+R_std_high, alpha=0.15)
plt.show()
# Out:
# (300,)

# %%
C_mean_high = np.array(C_mean_high)
print(C_mean_high.shape)
k = np.arange(0, 50*C_mean_high.shape[0], 50)
plt.plot(k, C_mean_high)
plt.show()
# Out:
# (300,)

# %%
# plot to compare
k = np.arange(0, 50*R_mean.shape[0], 50)
plt.plot(k, R_mean, label='original policy')
plt.fill_between(k, R_mean-R_std, R_mean + R_std, alpha=0.15)

k = np.arange(0, 50*R_mean_high.shape[0], 50)
plt.plot(k, R_mean_high, label='hierarchical policy')
plt.fill_between(k, R_mean_high-R_std_high, R_mean_high+R_std_high, alpha=0.15)
plt.xlim((0,15000))
plt.xlabel('steps', fontsize=12)
plt.ylabel('average reward', fontsize=12)
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %% [markdown]
# ### sampling

# %%
it = iter(val_dataloader)
x = next(it)

# %%
model_high.eval()
model_high.actor_net.decoder.decode_type = "stochastic"
model_low.eval()
model_low.actor_net.decoder.decode_type = "stochastic"

R_best = 1000
actions_low_best = 0
actions_high_best = 0
for i in range(100):
    _, C, _, actions_low, _, hidden_logits = model_low(x.cuda())
    hidden_logits = torch.stack(hidden_logits).detach()
    R, C, probs, actions, actions_idxs = model_high(x.cuda(),hidden_logits)
    if R_best > R.item():
        R_best = R.item()
        actions_low_best = actions_low
        actions_high_best = actions
        print("Reward:", R_best)
        print("Constraints:", C.item())
# Out:
# Reward: 7.361072540283203
# Constraints: 0.0
# Reward: 6.792172431945801
# Constraints: 0.0
# Reward: 6.720890045166016
# Constraints: 0.0
# Reward: 6.697376251220703
# Constraints: 0.0
# Reward: 6.46833610534668
# Constraints: 0.0
# Reward: 6.321874141693115
# Constraints: 0.0

# %%
print("Reward:", R_best)
# Out:
# Reward: 6.321874141693115

# %%
high_coor = np.zeros([50,2])
low_coor = np.zeros([50,2])
for i in range(50):
    high_coor[i,:] = actions_high_best[i].cpu()
    low_coor[i,:] = actions_low_best[i].cpu()

# plot low layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,1)
plt.plot(low_coor[:26,0], low_coor[:26,1], marker='s')
plt.plot(low_coor[25:,0], low_coor[25:,1], marker='s', c='green')
plt.plot([low_coor[-1,0], low_coor[0,0]], 
         [low_coor[-1,1], low_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.title('sampling 1000: low layer policy', fontsize=14)
plt.show()

# %%
# plot high layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,2)
plt.plot(high_coor[:26,0], high_coor[:26,1], marker='s')
plt.plot(high_coor[25:,0], high_coor[25:,1], marker='s', c='green')
plt.plot([high_coor[-1,0], high_coor[0,0]],
         [high_coor[-1,1], high_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.title('sampling 1000: hierarchical policy', fontsize=14)
plt.xlabel('length: 6.3219', fontsize=14)
plt.show()

# %% [markdown]
# ### random

# %%
model_high.eval()
model_high.actor_net.decoder.decode_type = "stochastic"
model_low.eval
model_low.actor_net.decoder.decode_type = "stochastic"


_, C, _, actions_low, _, hidden_logits = model_low(x.cuda())
hidden_logits = torch.stack(hidden_logits).detach()
R, C, probs, actions, actions_idxs = model_high(x.cuda(),hidden_logits)

print('Reward:', R.item())

high_coor = np.zeros([50,2])
low_coor = np.zeros([50,2])
for i in range(50):
    high_coor[i,:] = actions[i].cpu()
    low_coor[i,:] = actions_low[i].cpu()

# plot low layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,1)
plt.plot(low_coor[:26,0], low_coor[:26,1], marker='s')
plt.plot(low_coor[25:,0], low_coor[25:,1], marker='s', c='green')
plt.plot([low_coor[-1,0], low_coor[0,0]], 
         [low_coor[-1,1], low_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.title('sampling 1: low layer policy', fontsize=14)
plt.show()
# Out:
# Reward: 6.715628623962402

# %%
# plot high layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,2)
plt.plot(high_coor[:26,0], high_coor[:26,1], marker='s')
plt.plot(high_coor[25:,0], high_coor[25:,1], marker='s', c='green')
plt.plot([high_coor[-1,0], high_coor[0,0]],
         [high_coor[-1,1], high_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.xlabel('length: 6.7156', fontsize=14)
plt.title('sampling 1: hierarchical policy', fontsize=14)
plt.show()

# %% [markdown]
# ### greedy

# %%
model_high.eval()
model_high.actor_net.decoder.decode_type = "greedy"
model_low.eval
model_low.actor_net.decoder.decode_type = "greedy"


_, C, _, actions_low, _, hidden_logits = model_low(x.cuda())
hidden_logits = torch.stack(hidden_logits).detach()
R, C, probs, actions, actions_idxs = model_high(x.cuda(),hidden_logits)

print('Reward:', R.item())

high_coor = np.zeros([50,2])
low_coor = np.zeros([50,2])
for i in range(50):
    high_coor[i,:] = actions[i].cpu()
    low_coor[i,:] = actions_low[i].cpu()

# plot low layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,1)
plt.plot(low_coor[:26,0], low_coor[:26,1], marker='s')
plt.plot(low_coor[25:,0], low_coor[25:,1], marker='s', c='green')
plt.plot([low_coor[-1,0], low_coor[0,0]], 
         [low_coor[-1,1], low_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.title('greedy: low layer policy', fontsize=14)
plt.show()
# Out:
# Reward: 8.160735130310059

# %%
# plot high layer graph
plt.figure(figsize=(5,5))
# plt.subplot(2,1,2)
plt.plot(high_coor[:26,0], high_coor[:26,1], marker='s')
plt.plot(high_coor[25:,0], high_coor[25:,1], marker='s', c='green')
plt.plot([high_coor[-1,0], high_coor[0,0]],
         [high_coor[-1,1], high_coor[0,1]], marker='s', c='green')
plt.grid(None)
plt.title('greedy: hierarchical policy', fontsize=14)
plt.xlabel('length: 8.1607', fontsize=14)
plt.show()

# %%
test_coor = np.zeros([50,64,2])
test_idx = np.zeros([50,64])
for i in range(50):
    test_idx[i,:] = actions_idxs[i].cpu()
    test_coor[i,:] = actions[i].cpu()
    
test_graph = test_coor[:,0,:]
original_graph = x.numpy()[0,:,:]


plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
plt.scatter(original_graph[0], original_graph[1], marker='s')
plt.subplot(2,1,2)
plt.plot(test_graph[:26,0], test_graph[:26,1], marker='s')
plt.plot(test_graph[25:,0], test_graph[25:,1], marker='s', c='green')
plt.plot([test_graph[-1,0],test_graph[0,0]], 
         [test_graph[-1,1],test_graph[0,1]], marker='s', c='green')
plt.grid(None)

# %%
# validation
example_tour = []
avg_reward = []
val_step = 0
model.eval()
model.actor_net.decoder.decode_type = "greedy"
    
for batch_id, val_batch in enumerate(tqdm_notebook(val_dataloader)):
    bat = Variable(val_batch)

    if use_cuda:
        bat = bat.cuda()

    R, probs, actions, action_idxs = model(bat)
    avg_reward.append(R.mean().cpu().numpy())
    val_step += 1.

    if val_step % 5 == 0:
        example_output = []
        example_input = []
        for idx, action in enumerate(actions):

            example_output.append(action_idxs[idx][0].item())
            # example_input.append(bat[0, :, idx].item())
            # example_tour.append(action.item())
        print('Step: {}'.format(batch_id))
        #print('Example test input: {}'.format(example_input))
        print('Example test output: {}'.format(example_output))
        print('Example test reward: {}'.format(R.mean()))

print('Validation overall avg_reward: {}'.format(np.mean(avg_reward)))
print('Validation overall reward var: {}'.format(np.var(avg_reward)))
